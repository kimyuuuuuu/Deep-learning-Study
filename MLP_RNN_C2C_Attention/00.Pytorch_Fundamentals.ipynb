# %% [markdown]
# # PyTorch Fundamentals
# 1. What are Tensors?
# 2. Tensor Initialization
# 3. Common Tensor Initialization Methods
# 4. Tensor Type Conversion
# 5. Converting Between NumPy Arrays and Tensors
# 6. Tensor Mathematics and Comparison Operations
# 7. Matrix Multiplication and Batch Operations
# 8. Broadcasting and Other Useful Operations
# 9. Tensor Indexing
# 10. Tensor Reshaping

# %%
import torch 
import numpy as np 
import warnings
warnings.filterwarnings('ignore')

print("torch version:", torch.__version__)
print("numpy version:", np.__version__)
# Out:
# torch version: 2.7.1+cpu
# numpy version: 2.2.6
